# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivamSinghal1/Fake-News-Detector/blob/master/Related_News.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
input_news = """
    Indian Government plan for extended lockdown after 21 days.
"""

# %%
import requests
from bs4 import BeautifulSoup as soup
# !pip install rake_nltk
from rake_nltk import Rake
# Out:
# Collecting rake_nltk
#   Downloading https://files.pythonhosted.org/packages/8e/c4/b4ff57e541ac5624ad4b20b89c2bafd4e98f29fd83139f3a81858bdb3815/rake_nltk-1.0.4.tar.gz
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from rake_nltk) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk->rake_nltk) (1.12.0)
# Building wheels for collected packages: rake-nltk
#   Building wheel for rake-nltk (setup.py) ... done
#   Created wheel for rake-nltk: filename=rake_nltk-1.0.4-py2.py3-none-any.whl size=7819 sha256=aa2f6b51fb28be4aa4a0ae48dd881f62cbdd5dcc39151aedcef5b1d9d2929c44
#   Stored in directory: /root/.cache/pip/wheels/ef/92/fc/271b3709e71a96ffe934b27818946b795ac6b9b8ff8682483f
# Successfully built rake-nltk
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.4

# %%
r = Rake()
r.extract_keywords_from_text(input_news)
keywords = r.get_ranked_phrases()[:5]
query = " "
query = query.join(keywords)

# %%
url = "https://news.google.com/search?q=" + query
res = requests.get(url)

# %%
soup = soup(res.content)
all_news = soup.findAll('div', {'class' : 'NiLAwe y6IFtc R7GTQ keNKEd j7vNaf nID9nc'})

# %%
related_news = []
for news in all_news:
    temp = {}
    temp['title'] = news.find('h3').find('a').text
    temp['biliner'] = news.find('span' , {'class' : 'xBbh9'}).text
    temp['img'] = news.find('a').find('img')["src"]
    temp['link'] = "https://news.google.com" + news.find('h3').find('a')['href'][1:]
    temp['time'] = news.find('time')['datetime']
    temp['source'] = news.find('a', {'class' : 'wEwyrc AVN2gc uQIVzc Sksgp'}).text
    related_news.append(temp)

# %%
### Output related_news
print(related_news)
# Out:
# [{'title': 'Coronavirus: No plan to extend 21-day lockdown, govt says', 'biliner': 'India News: The government on Monday said there was no plan to extend the 21-day lockdown which came intro force on Tuesday midnight. The Press ...', 'img': 'https://lh3.googleusercontent.com/y3cxEJa6QGLLAOX8puJzM1nDbizhN5RWOMQ57vEbZCDXWMjylQmPoUyHlUZPX9uBcrCRzMEfOs4nr7Q7nDc=-p-h100-w100', 'link': 'https://news.google.com/articles/CAIiEInhd2_DOr2cHKhxjlYdK64qGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-US&gl=US&ceid=US%3Aen', 'time': '2020-03-30T08:51:40Z', 'source': 'Times of India'}, {'title': 'India has no plans to extend 21 days lockdown', 'biliner': 'Dismissing the rumors that the government could extend 21-day lockdown, Cabinet Secretary Rajiv Gauba told that there was no plan to extend the shutdown ...', 'img': 'https://lh5.googleusercontent.com/proxy/65UoqwnzOG9ZRSX3lc3a2jLDfNXgyZLGPBUU06xDbakgmz4TDQ3_EY_aiY7msUr66U24kyfXAlF1YzaGPFljNMqn6tV648o7sZGqac9qyzqz41r95OeiCOCmnfR-f0DOeKPHe4HFadmtim1s2Oz4d7TaHuNdDb9fW39qE_Vaj-iOaQAaLH_4Y2G7z6U=-p-h100-w100', 'link': 'https://news.google.com/articles/CBMiT2h0dHBzOi8vc2Vla2luZ2FscGhhLmNvbS9uZXdzLzM1NTYxMzgtaW5kaWEtbm8tcGxhbnMtdG8tZXh0ZW5kLTIxLWRheXMtbG9ja2Rvd27SAVNodHRwczovL3NlZWtpbmdhbHBoYS5jb20vYW1wL25ld3MvMzU1NjEzOC1pbmRpYS1uby1wbGFucy10by1leHRlbmQtMjEtZGF5cy1sb2NrZG93bg?hl=en-US&gl=US&ceid=US%3Aen', 'time': '2020-03-30T08:39:00Z', 'source': 'Seeking Alpha'}, {'title': "India automaker Maruti Suzuki made 'no sales' since virus lockdown, but chairman believes crisis will pass", 'biliner': "Maruti Suzuki Chairman R.C. Bhargava told CNBC it wasn't clear when demand would return as India's lockdown is set to end on April 14.", 'img': 'https://lh3.googleusercontent.com/Zh5oZJoyik6ShccJcT-j6dObqpbqLZ-zmBnh2ap0tPP8Pvf-BZIRTzxheaj2X8fLfHrgCXjNXx2OYEi1QA=-p-h100-w100', 'link': 'https://news.google.com/articles/CAIiEJ4sPN2mFgtn8clMLknzqL8qGQgEKhAIACoHCAow2Nb3CjDivdcCMJ-thQY?hl=en-US&gl=US&ceid=US%3Aen', 'time': '2020-04-02T04:35:12Z', 'source': 'CNBC'}, {'title': 'Govt health experts recommend lockdown extension as migrant exodus ‘undermines’ containment', 'biliner': "21-day lockdown will help, but top health experts working closely with PM Modi's Covid-19 team recommend it should be extended due to exodus.", 'img': 'https://lh6.googleusercontent.com/proxy/SQU697qY6IM7L4yp1V2dG-yZ56KM4kbESNUTthzRCps6nb4uZqC-7FlrHYRU6UPTGaB-rCiTAzGId5kV3fl1zgo95hvumkv4Et229dnQGiyeaUpJCjeoVGaUBv_Lmq-PoP4=-p-h100-w100', 'link': 'https://news.google.?hl=en-US&gl=US&ceid=US%3Aen', 'time': '2020-03-30T12:23:34Z', 'source': 'ThePrint'}, {'title': 'Coronavirus India lockdown day 7 updates | March 31, 2020', 'biliner': 'As India is under lockdown for a week now, the government has said the 21-day period will not be extended. The country is seeing a spurt in the number of ...', 'img': 'https://lh3.googleusercontent.com/D78d4L4mdAl2JZcEA8idIS-GGivsG2cNN5f0NCuwDKNg3fRVh7BVa0yLfvUIAKiPwB8gvIaNHreTFn3J0Q=-p-h100-w100', 'link': 'https://news.google.com/articles/CAIiEAbk5hpBjur5v0vv6gp2xFEqGQgEKhAIACoHCAowiYr-CjD1iIoDMODSzwY?hl=en-US&gl=US&ceid=US%3Aen', 'time': '2020-03-31T14:00:05Z', 'source': 'The Hindu'}, {'title': 'A 90-day action plan to beat back the virus', 'biliner': 'HYDERABAD : The situation is grim and is getting worse by the day. While the government is bravely talking of its 21-day target to tide over the covid-19 crisis, ...', 'img': 'https://lh6.googleusercontent.com/proxy/E6mJPQ4cFIc8XWbjmrXwOLZ-1IzlbxjCYzqFEeFaB9uCv2N2-URPFDeE_sGyB1RgqkDKvIN3C_hAam4GP9ZTByg6mIYCLfZ26JTDWnSR6CxCZ5lRQmQkhnqGGM5hg6lVqGSJQJm3sKWBZi4=-p-h100-w100', 'link': 'https ...
